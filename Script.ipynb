# %%
import numpy
import sys

# %%
run src/data/make_dataset.py
# Out:
# 2021-06-09 11:09:30,632 - __main__ - INFO - making final data set from raw data

# %%
trainloader, testloader = main()
# Out:
# 2021-06-09 11:09:31,193 - builtins - INFO - making final data set from raw data

# %%
run src/models/model.py

# %%
model = MyAwesomeModel()
model
# Out:
# MyAwesomeModel(
#   (conv_1): Conv2d(1, 24, kernel_size=(4, 4), stride=(1, 1), padding=(2, 2))
#   (dropout): Dropout2d(p=0.5, inplace=False)
#   (batchnormInput): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (l_1): Linear(in_features=20184, out_features=100, bias=True)
#   (l_out): Linear(in_features=100, out_features=10, bias=False)
# )

# %%
run src/models/main.py train
# Out:
# 2021-06-09 11:01:11,309 - make_dataset - INFO - making final data set from raw data
# Training day and night
# Namespace(lr=0.1)
# Epoch 1
# Epoch 2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/Documents/DTU/MLOps/Day 2/Organised code/src/models/main.py in <module>
#     134
#     135 if __name__ == '__main__':
# --> 136     TrainOREvaluate()
#     137
#     138
#
# ~/Documents/DTU/MLOps/Day 2/Organised code/src/models/main.py in __init__(self)
#      44             exit(1)
#      45         # use dispatch pattern to invoke method with same name
# ---> 46         getattr(self, args.command)()
#      47
#      48     def train(self):
#
# ~/Documents/DTU/MLOps/Day 2/Organised code/src/models/main.py in train(self)
#      81                 loss = criterion(output,labels)
#      82                 optimizer.zero_grad()
# ---> 83                 loss.backward()
# ...

# %%
numpy.save('images.npy', next(iter(testloader))[0].numpy())

# %%
run src/models/predict_model.py predict

# %%
run src/visualization/visualize.py visualise
# Out:
# 2021-06-07 14:02:23,628 - make_dataset - INFO - making final data set from raw data
# Visualising the input!
# Namespace(load_model_from='checkpoint.pth')
